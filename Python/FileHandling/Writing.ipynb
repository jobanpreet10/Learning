# %% [markdown]
# w overwrite the file if the file exist and create a new file if and writes if the file doesnot exist.

# %%
file = "text.txt"
with open(file,"w") as f:
    f.write("Hi")
f.close()

# %%
with open(file,'a') as f:
    f.write(" there")
    f.write("\n How are you Priyanshu")

# %%
with open(file,'r') as f:
    print(f.read())
# Out:
# Hi there
#  How are you Priyanshu

# %%
f = open(file)
print(f.read())
# Out:
# Hi there
#  How are you Priyanshu
