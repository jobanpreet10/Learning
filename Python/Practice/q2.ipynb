# %%
with open("sample1.txt",'w',newline='') as f:
    f.write("Hi I am Joban")
# Out:
# Hi I am Joban

# %%
passed = [1,2,3,4,5,6,7]
passed = [x for x in passed if x > 4]
passed
# Out:
# [5, 6, 7]

# %%
print
