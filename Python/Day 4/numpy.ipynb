# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.0

# %%
data = pd.read_csv('top_rated_movies.csv')

# %%
data
# Out:
#        Unnamed: 0      id                                       title  \
# 0               0     278                    The Shawshank Redemption
# 1               1     238                               The Godfather
# 2               2     240                       The Godfather Part II
# 3               3     424                            Schindler's List
# 4               4     389                                12 Angry Men
# ...           ...     ...                                         ...
# 18515       18515  531949                          Father of the Year
# 18516       18516   37931                                   MacGruber
# 18517       18517  340677                                        I.T.
# 18518       18518   10160  A Nightmare on Elm Street: The Dream Child
# 18519       18519   11425                  Honey, We Shrunk Ourselves
#
#                                                 overview release_date  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18520 entries, 0 to 18519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18520 non-null  int64
#  1   id            18520 non-null  int64
#  2   title         18520 non-null  str
#  3   overview      18518 non-null  str
#  4   release_date  18516 non-null  str
#  5   popularity    18520 non-null  float64
#  6   vote_average  18520 non-null  float64
#  7   vote_count    18520 non-null  int64
# dtypes: float64(2), int64(3), str(3)
# memory usage: 1.1 MB

# %%
data.dtypes
# Out:
# Unnamed: 0        int64
# id                int64
# title               str
# overview            str
# release_date        str
# popularity      float64
# vote_average    float64
# vote_count        int64
# dtype: object

# %%
data.describe()
# Out:
#          Unnamed: 0            id    popularity  vote_average    vote_count
# count  18520.000000  1.852000e+04  18520.000000  18520.000000  18520.000000
# mean    9259.500000  2.239016e+05      4.216869      6.802412   2148.693143
# std     5346.407828  2.980745e+05      8.833169      0.623615   3402.029522
# min        0.000000  2.000000e+00      0.003100      5.400000    300.000000
# 25%     4629.750000  1.020700e+04      1.818400      6.319750    480.000000
# 50%     9259.500000  3.910800e+04      2.907100      6.781500    893.000000
# 75%    13889.250000  4.036050e+05      4.888125      7.254000   2168.250000
# max    18519.000000  1.472638e+06    567.760800      8.715000  38665.000000

# %%
data['title']
# Out:
# 0                          The Shawshank Redemption
# 1                                     The Godfather
# 2                             The Godfather Part II
# 3                                  Schindler's List
# 4                                      12 Angry Men
#                             ...
# 18515                            Father of the Year
# 18516                                     MacGruber
# 18517                                          I.T.
# 18518    A Nightmare on Elm Street: The Dream Child
# 18519                    Honey, We Shrunk Ourselves
# Name: title, Length: 18520, dtype: str

# %%
data[['title','overview']]
# Out:
#                                             title  \
# 0                        The Shawshank Redemption
# 1                                   The Godfather
# 2                           The Godfather Part II
# 3                                Schindler's List
# 4                                    12 Angry Men
# ...                                           ...
# 18515                          Father of the Year
# 18516                                   MacGruber
# 18517                                        I.T.
# 18518  A Nightmare on Elm Street: The Dream Child
# 18519                  Honey, We Shrunk Ourselves
#
#                                                 overview
# 0      Imprisoned in the 1940s for the double murder ...
# 1      Spanning the years 1945 to 1955, a chronicle o...
# 2      In the continuing saga of the Corleone crime f...
# 3      The true story of how businessman Oskar Schind...
# 4      The defense and the prosecution have rested an...
# ...

# %% [markdown]
# Data Engineering focuses on building pipelines to collect , transforman and store data
# Used in :
#     Analytics
#     AI System
#     Business Dashboard
#
#
# Dataset is decnormalized table.

# %%
# filtering of the data 
data[(data['vote_count'] > 30000)]

data[(data['vote_count'] > 30000) & (data['vote_average'] > 2)]
# Out:
#       Unnamed: 0      id                   title  \
# 6              6     155         The Dark Knight
# 14            14  157336            Interstellar
# 20            20     550              Fight Club
# 41            41   27205               Inception
# 94            94  299536  Avengers: Infinity War
# 400          400   24428            The Avengers
# 969          969  293660                Deadpool
# 1032        1032   19995                  Avatar
# 8566        8566     155         The Dark Knight
# 8574        8574  157336            Interstellar
# 8580        8580     550              Fight Club
# 8601        8601   27205               Inception
# 8654        8654  299536  Avengers: Infinity War
# 8960        8960   24428            The Avengers
# 9529        9529  293660                Deadpool
# 9592        9592   19995                  Avatar
#
#                                                overview release_date  \
# ...

# %%
#  other way  creating a mask 
mask = data['vote_count'] > 3000
data[mask]
# Out:
#        Unnamed: 0      id                            title  \
# 0               0     278         The Shawshank Redemption
# 1               1     238                    The Godfather
# 2               2     240            The Godfather Part II
# 3               3     424                 Schindler's List
# 4               4     389                     12 Angry Men
# ...           ...     ...                              ...
# 18403       18403    9471  Charlie's Angels: Full Throttle
# 18452       18452   76757                Jupiter Ascending
# 18461       18461     414                   Batman Forever
# 18490       18490  121856                 Assassin's Creed
# 18491       18491   96936                   The Bling Ring
#
#                                                 overview release_date  \
# 0      Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# ...

# %%
# create a new column

data['avg_cnt'] = data['vote_count']*data['vote_average']

# %% [markdown]
# If more null values
# dont remove them from the dataframe

# %%
# Sorting the data 

data.sort_values('vote_average',ascending=False)
# Out:
#        Unnamed: 0      id                                           title  \
# 0               0     278                        The Shawshank Redemption
# 8560         8560     278                        The Shawshank Redemption
# 1               1     238                                   The Godfather
# 8561         8561     238                                   The Godfather
# 4               4     389                                    12 Angry Men
# ...           ...     ...                                             ...
# 18483       18483  505063                      Await Further Instructions
# 18493       18493  530081  The Man Who Killed Hitler and Then the Bigfoot
# 18497       18497   10658                                 Howard the Duck
# 18499       18499    8944                              What Just Happened
# 18476       18476  362826                                        Wildling
#
#                                                 overview release_date  \
# ...

# %%
#  use of group by 
data.groupby('release_date').size()
# Out:
# release_date
# 1902-06-15    2
# 1903-12-07    2
# 1915-03-08    1
# 1916-09-04    2
# 1917-06-17    2
#              ..
# 2025-12-03    2
# 2025-12-17    2
# 2025-12-18    2
# 2025-12-25    2
# 2026-01-13    2
# Length: 6232, dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# id              0
# title           0
# overview        2
# release_date    4
# popularity      0
# vote_average    0
# vote_count      0
# avg_cnt         0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# id              0
# title           0
# overview        0
# release_date    0
# popularity      0
# vote_average    0
# vote_count      0
# avg_cnt         0
# dtype: int64

# %%
data.to_csv('processed_data.csv')

# %%
data.drop_duplicates(keep='first',inplace=True)

# %%
# x = data.sort_values('vote_average',ascending=False)
# Out:
#        Unnamed: 0      id                                       title  \
# 0               0     278                    The Shawshank Redemption
# 1               1     238                               The Godfather
# 2               2     240                       The Godfather Part II
# 3               3     424                            Schindler's List
# 4               4     389                                12 Angry Men
# ...           ...     ...                                         ...
# 18515       18515  531949                          Father of the Year
# 18516       18516   37931                                   MacGruber
# 18517       18517  340677                                        I.T.
# 18518       18518   10160  A Nightmare on Elm Street: The Dream Child
# 18519       18519   11425                  Honey, We Shrunk Ourselves
#
#                                                 overview release_date  \
# ...

# %%
# x.head(6)
# Out:
#       Unnamed: 0   id                     title  \
# 0              0  278  The Shawshank Redemption
# 8560        8560  278  The Shawshank Redemption
# 1              1  238             The Godfather
# 8561        8561  238             The Godfather
# 4              4  389              12 Angry Men
# 3              3  424          Schindler's List
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 8560  Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 8561  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 4     The defense and the prosecution have rested an...   1957-04-10
# 3     The true story of how businessman Oskar Schind...   1993-12-15
#
#       popularity  vote_average  vote_count     avg_cnt
# 0        32.2333         8.715       29566  257667.690
# ...
