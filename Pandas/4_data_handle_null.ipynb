# %%
# check for the entire fram 

import pandas as pd

# %%
df = pd.read_csv('StudentPerformanceFactors.csv')
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
mask = df.isna() | (df == "")

# %%
df[mask.any(axis= 1)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 33               14          60                 High              Medium
# 127              17          97               Medium              Medium
# 240              15          87                  Low              Medium
# 275              23          82                  Low              Medium
# 316              24          90                  Low                 Low
# ...             ...         ...                  ...                 ...
# 6502             23          64               Medium              Medium
# 6579              9          84               Medium              Medium
# 6589             22          90                  Low                High
# 6594              9          90                 High                High
# 6596             17          92               Medium              Medium
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df[(df.isna() | (df == "")).any(axis=1)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 33               14          60                 High              Medium
# 127              17          97               Medium              Medium
# 240              15          87                  Low              Medium
# 275              23          82                  Low              Medium
# 316              24          90                  Low                 Low
# ...             ...         ...                  ...                 ...
# 6502             23          64               Medium              Medium
# 6579              9          84               Medium              Medium
# 6589             22          90                  Low                High
# 6594              9          90                 High                High
# 6596             17          92               Medium              Medium
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
# to replace all the changes in one go 
df.fillna({
    'Teacher_Quality': "Low",
    'Parental_Education_Level': "School",
    'Distance_from_Home': "Near"
}, inplace=True)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df[df['Physical_Activity'] > 3]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# 9                23          98               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6592             29         100               Medium                 Low
# 6593             16          75                 High                 Low
# 6594              9          90                 High                High
# 6601             20          83               Medium                 Low
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
# Count per category
df['Access_to_Resources'].value_counts()

# or
# Out:
# Access_to_Resources
# Medium    3319
# High      1975
# Low       1313
# Name: count, dtype: int64

# %%
df.groupby('Access_to_Resources')['Access_to_Resources'].count()
# Out:
# Access_to_Resources
# High      1975
# Low       1313
# Medium    3319
# Name: Access_to_Resources, dtype: int64

# %%
# 📊 Average hours of sleep grouped by Access_to_Resources


# df.groupby('Access_to_Resources')['Sleep_Hours'].sum()/df.groupby('Access_to_Resources').size()
# Out:
# Access_to_Resources  Hours_Studied  Attendance  Parental_Involvement  Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  Teacher_Quality  School_Type  Peer_Influence  Physical_Activity  Learning_Disabilities  Parental_Education_Level  Distance_from_Home  Gender  Exam_Score
# High                 23             84          Low                   No                          7            73               Low               Yes              0                  Low            Medium           Public       Positive        3                  No                     High School               Near                Male    67            13863.0
# ...
